# %%
from tkinter import *
def btnClick(numbers):
    global operator
    operator=operator+str(numbers)
    text_input.set(operator)
    
def clearDisplay():
    global operator
    operator=""
    text_input.set("")
    
def equalDisplay():
    global operator
    answer=str(eval(operator))
    text_input.set(answer)
    operator=""

cal=Tk()
cal.title("calculator")

operator=''
text_input=StringVar()

text_display=Entry(cal,font=('areal',20,'bold'),bd=30,textvariable=text_input,insertwidth=4).grid(columnspan=4)

btn7=Button(cal,text='7',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(7)).grid(row=1,column=0)
btn8=Button(cal,text='8',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(8)).grid(row=1,column=1)
btn9=Button(cal,text='9',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(9)).grid(row=1,column=2)
Addition=Button(cal,text='+',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("+")).grid(row=1,column=3)

#================================================================================================
btn4=Button(cal,text='4',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(4)).grid(row=2,column=0)
btn5=Button(cal,text='5',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(5)).grid(row=2,column=1)
btn6=Button(cal,text='6',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(6)).grid(row=2,column=2)
Substraction=Button(cal,text='-',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("-")).grid(row=2,column=3)

#================================================================================================
btn1=Button(cal,text='1',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(1)).grid(row=3,column=0)
btn2=Button(cal,text='2',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(2)).grid(row=3,column=1)
btn3=Button(cal,text='3',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(3)).grid(row=3,column=2)
Multiply=Button(cal,text='*',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("*")).grid(row=3,column=3)

#================================================================================================
btn0=Button(cal,text='0',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(0)).grid(row=4,column=0)
btnClear=Button(cal,text='C',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=clearDisplay).grid(row=4,column=1)
btnEquals=Button(cal,text='=',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=equalDisplay).grid(row=4,column=2)
Divide=Button(cal,text='/',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("/")).grid(row=4,column=3)

#================================================================================================

cal.mainloop()

# %%
from tkinter import ttk
cal=Tk()
cal.title("calculator")
operator=''

def btnClick(numbers):
    global operator
    operator=operator+str(numbers)
    text_input.set(operator)
    
def clearDisplay():
    global operator
    operator=""
    text_input.set("0")
    
def equalDisplay():
    global operator
    if ("+" and "-") or("+" and "*") or("+" and "/") or("-" and "*") or("-" and "/") or("*" and "/") in operator:  
        text_input.set("invalid syntax")
    elif operator=="":
        text_input.set("0")
    else:
        answer=str(eval(operator))
        text_input.set(answer)
        operator=""



text_input=StringVar()

text_display=Entry(cal,font=('areal',20,'bold'),bd=30,textvariable=text_input,insertwidth=4).grid(columnspan=4)

btn7=Button(cal,text='7',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(7)).grid(row=1,column=0)
btn8=Button(cal,text='8',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(8)).grid(row=1,column=1)
btn9=Button(cal,text='9',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(9)).grid(row=1,column=2)
Addition=Button(cal,text='+',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("+")).grid(row=1,column=3)

btn4=Button(cal,text='4',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(4)).grid(row=2,column=0)
btn5=Button(cal,text='5',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(5)).grid(row=2,column=1)
btn6=Button(cal,text='6',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(6)).grid(row=2,column=2)
Substraction=Button(cal,text='-',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("-")).grid(row=2,column=3)

btn1=Button(cal,text='1',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(1)).grid(row=3,column=0)
btn2=Button(cal,text='2',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(2)).grid(row=3,column=1)
btn3=Button(cal,text='3',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(3)).grid(row=3,column=2)
Multiply=Button(cal,text='*',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("*")).grid(row=3,column=3)

btn0=Button(cal,text='0',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick(0)).grid(row=4,column=0)
btnClear=Button(cal,text='C',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=clearDisplay).grid(row=4,column=1)
btnEquals=Button(cal,text='=',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=equalDisplay).grid(row=4,column=2)
Divide=Button(cal,text='/',padx=16,pady=16,bd=8,font=('areal',20,'bold'),command=lambda:btnClick("/")).grid(row=4,column=3)


cal.mainloop()

# %%
from tkinter import *
root=Tk()
root.title("calculator")

op=''

def result(numbers):
    global op
    op=op+str(numbers)
    uservalue.set(op)

def clear():
    global op
    uservalue.set("")
    op=""

def answer():
    global op
    ans=eval(op)
    uservalue.set(ans)
    op=""
        
uservalue=StringVar()

userentry=Entry(root,textvariable=uservalue,insertwidth=4,font=('algerian',20,'bold'),bd=8,justify='right').grid(columnspan=8)

b1=Button(root,text="7",command=lambda:result(7),padx=30,pady=10,bd=8).grid(row=2,column=1)
b2=Button(root,text="8",command=lambda:result(8),padx=30,pady=10,bd=8).grid(row=2,column=2)
b3=Button(root,text="9",command=lambda:result(9),padx=30,pady=10,bd=8).grid(row=2,column=3)
b4=Button(root,text="/",command=lambda:result("/"),padx=30,pady=10,bd=8).grid(row=2,column=4)
b5=Button(root,text="4",command=lambda:result(4),padx=30,pady=10,bd=8).grid(row=3,column=1)
b6=Button(root,text="5",command=lambda:result(5),padx=30,pady=10,bd=8).grid(row=3,column=2)
b7=Button(root,text="6",command=lambda:result(6),padx=30,pady=10,bd=8).grid(row=3,column=3)
b8=Button(root,text="*",command=lambda:result("*"),padx=30,pady=10,bd=8).grid(row=3,column=4)
b9=Button(root,text="1",command=lambda:result(1),padx=30,pady=10,bd=8).grid(row=4,column=1)
b10=Button(root,text="2",command=lambda:result(2),padx=30,pady=10,bd=8).grid(row=4,column=2)
b11=Button(root,text="3",command=lambda:result(3),padx=30,pady=10,bd=8).grid(row=4,column=3)
b12=Button(root,text="-",command=lambda:result("-"),padx=30,pady=10,bd=8).grid(row=4,column=4)
b13=Button(root,text=".",command=lambda:result("."),padx=30,pady=10,bd=8).grid(row=5,column=1)
b14=Button(root,text="0",command=lambda:result(0),padx=30,pady=10,bd=8).grid(row=5,column=2)
b15=Button(root,text="C",command=clear,padx=30,pady=10,bd=8).grid(row=5,column=3)
b16=Button(root,text="+",command=lambda:result("+"),padx=30,pady=10,bd=8).grid(row=5,column=4)
b17=Button(root,text="=",padx=30,command=answer,pady=10,bd=8,width=40).grid(columnspan=8)
root.mainloop()
